# %%
# !pip install pycaret[full]
# Out:
# Requirement already satisfied: pycaret[full] in ./.venv/lib/python3.11/site-packages (3.3.0)
# Requirement already satisfied: ipython>=5.5.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (8.23.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (8.1.2)
# Requirement already satisfied: tqdm>=4.62.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (4.66.2)
# Requirement already satisfied: numpy<1.27,>=1.21 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (2.1.4)
# Requirement already satisfied: jinja2>=3 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (3.1.3)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (1.4.1.post1)
# Requirement already satisfied: pyod>=1.1.3 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (1.1.3)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.12.2)
# Requirement already satisfied: category-encoders>=2.4.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (2.6.3)
# Requirement already satisfied: lightgbm>=3.0.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (4.3.0)
# Requirement already satisfied: numba>=0.55.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.59.1)
# Requirement already satisfied: requests>=2.27.1 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (2.31.0)
# Requirement already satisfied: psutil>=5.9.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (5.9.8)
# Requirement already satisfied: markupsafe>=2.0.1 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (2.1.5)
# Requirement already satisfied: importlib-metadata>=4.12.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (7.1.0)
# Requirement already satisfied: nbformat>=4.2.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (5.10.3)
# Requirement already satisfied: cloudpickle in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (3.0.0)
# Requirement already satisfied: deprecation>=2.1.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (2.1.0)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (3.4.1)
# Requirement already satisfied: matplotlib<3.8.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (5.20.0)
# Requirement already satisfied: kaleido>=0.2.1 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.14.1)
# Requirement already satisfied: sktime>=0.26.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.28.0)
# Requirement already satisfied: tbats>=1.1.3 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (2.0.4)
# Requirement already satisfied: wurlitzer in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (3.0.3)
# Requirement already satisfied: shap>=0.44.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.45.0)
# Requirement already satisfied: interpret>=0.2.7 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.6.0)
# Requirement already satisfied: umap-learn>=0.5.2 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.5.6)
# Requirement already satisfied: pyyaml==5.3.1 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (5.3.1)
# Requirement already satisfied: ydata-profiling>=4.3.1 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (4.7.0)
# Requirement already satisfied: explainerdashboard>=0.3.8 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.4.7)
# Requirement already satisfied: fairlearn==0.7.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.7.0)
# Requirement already satisfied: kmodes>=0.11.1 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.12.2)
# Requirement already satisfied: mlxtend>=0.19.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.23.1)
# Requirement already satisfied: statsforecast<1.6.0,>=0.5.5 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (1.5.0)
# Requirement already satisfied: hyperopt>=0.2.7 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.2.7)
# Requirement already satisfied: optuna>=3.0.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (3.6.1)
# Requirement already satisfied: scikit-optimize>=0.9.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.10.1)
# Requirement already satisfied: mlflow>=2.0.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (2.11.3)
# Requirement already satisfied: gradio>=3.50.2 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (4.25.0)
# Requirement already satisfied: boto3>=1.24.56 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (1.34.77)
# Requirement already satisfied: fastapi in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.110.1)
# Requirement already satisfied: uvicorn>=0.17.6 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.29.0)
# Requirement already satisfied: m2cgen>=0.9.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.10.0)
# Requirement already satisfied: evidently in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.4.16)
# Requirement already satisfied: fugue in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.8.6)
# Requirement already satisfied: flask in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (2.3.3)
# Requirement already satisfied: Werkzeug<3.0,>=2.2 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (2.3.8)
# Requirement already satisfied: triad<0.9.2 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.9.1)
# Requirement already satisfied: pytest<8.0.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (7.4.4)
# Requirement already satisfied: moto<5.0.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (4.2.14)
# Requirement already satisfied: dash[testing] in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (2.16.1)
# Requirement already satisfied: scikit-learn-intelex>=2023.0.1 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (2024.2.0)
# Requirement already satisfied: catboost>=0.23.2 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (1.2.3)
# Requirement already satisfied: xgboost>=1.1.0 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (2.0.3)
# Requirement already satisfied: tune-sklearn>=0.2.1 in ./.venv/lib/python3.11/site-packages (from pycaret[full]) (0.5.0)
# Requirement already satisfied: ray>=1.0.0 in ./.venv/lib/python3.11/site-packages (from ray[tune]>=1.0.0; (python_version != "3.11" or platform_system != "Windows") and extra == "full"->pycaret[full]) (2.10.0)
# Requirement already satisfied: botocore<1.35.0,>=1.34.77 in ./.venv/lib/python3.11/site-packages (from boto3>=1.24.56->pycaret[full]) (1.34.77)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./.venv/lib/python3.11/site-packages (from boto3>=1.24.56->pycaret[full]) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in ./.venv/lib/python3.11/site-packages (from boto3>=1.24.56->pycaret[full]) (0.10.1)
# Requirement already satisfied: graphviz in ./.venv/lib/python3.11/site-packages (from catboost>=0.23.2->pycaret[full]) (0.20.3)
# Requirement already satisfied: six in ./.venv/lib/python3.11/site-packages (from catboost>=0.23.2->pycaret[full]) (1.16.0)
# Requirement already satisfied: patsy>=0.5.1 in ./.venv/lib/python3.11/site-packages (from category-encoders>=2.4.0->pycaret[full]) (0.5.6)
# Requirement already satisfied: packaging in ./.venv/lib/python3.11/site-packages (from deprecation>=2.1.0->pycaret[full]) (23.2)
# Requirement already satisfied: click in ./.venv/lib/python3.11/site-packages (from explainerdashboard>=0.3.8->pycaret[full]) (8.1.7)
# Requirement already satisfied: dash-auth in ./.venv/lib/python3.11/site-packages (from explainerdashboard>=0.3.8->pycaret[full]) (2.3.0)
# Requirement already satisfied: dash-bootstrap-components>=1 in ./.venv/lib/python3.11/site-packages (from explainerdashboard>=0.3.8->pycaret[full]) (1.5.0)
# Requirement already satisfied: dtreeviz>=2.1 in ./.venv/lib/python3.11/site-packages (from explainerdashboard>=0.3.8->pycaret[full]) (2.2.2)
# Requirement already satisfied: flask-simplelogin in ./.venv/lib/python3.11/site-packages (from explainerdashboard>=0.3.8->pycaret[full]) (0.1.2)
# Requirement already satisfied: Flask-WTF>=1.1 in ./.venv/lib/python3.11/site-packages (from explainerdashboard>=0.3.8->pycaret[full]) (1.2.1)
# Requirement already satisfied: jupyter-dash>=0.4.1 in ./.venv/lib/python3.11/site-packages (from explainerdashboard>=0.3.8->pycaret[full]) (0.4.2)
# Requirement already satisfied: oyaml in ./.venv/lib/python3.11/site-packages (from explainerdashboard>=0.3.8->pycaret[full]) (1.0)
# Requirement already satisfied: waitress in ./.venv/lib/python3.11/site-packages (from explainerdashboard>=0.3.8->pycaret[full]) (3.0.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in ./.venv/lib/python3.11/site-packages (from gradio>=3.50.2->pycaret[full]) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in ./.venv/lib/python3.11/site-packages (from gradio>=3.50.2->pycaret[full]) (5.3.0)
# Requirement already satisfied: ffmpy in ./.venv/lib/python3.11/site-packages (from gradio>=3.50.2->pycaret[full]) (0.3.2)
# Requirement already satisfied: gradio-client==0.15.0 in ./.venv/lib/python3.11/site-packages (from gradio>=3.50.2->pycaret[full]) (0.15.0)
# Requirement already satisfied: httpx>=0.24.1 in ./.venv/lib/python3.11/site-packages (from gradio>=3.50.2->pycaret[full]) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in ./.venv/lib/python3.11/site-packages (from gradio>=3.50.2->pycaret[full]) (0.22.2)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in ./.venv/lib/python3.11/site-packages (from gradio>=3.50.2->pycaret[full]) (6.4.0)
# Requirement already satisfied: orjson~=3.0 in ./.venv/lib/python3.11/site-packages (from gradio>=3.50.2->pycaret[full]) (3.10.0)
# Requirement already satisfied: pillow<11.0,>=8.0 in ./.venv/lib/python3.11/site-packages (from gradio>=3.50.2->pycaret[full]) (10.3.0)
# Requirement already satisfied: pydantic>=2.0 in ./.venv/lib/python3.11/site-packages (from gradio>=3.50.2->pycaret[full]) (2.6.4)
# Requirement already satisfied: pydub in ./.venv/lib/python3.11/site-packages (from gradio>=3.50.2->pycaret[full]) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in ./.venv/lib/python3.11/site-packages (from gradio>=3.50.2->pycaret[full]) (0.0.9)
# Requirement already satisfied: ruff>=0.2.2 in ./.venv/lib/python3.11/site-packages (from gradio>=3.50.2->pycaret[full]) (0.3.5)
# Requirement already satisfied: semantic-version~=2.0 in ./.venv/lib/python3.11/site-packages (from gradio>=3.50.2->pycaret[full]) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in ./.venv/lib/python3.11/site-packages (from gradio>=3.50.2->pycaret[full]) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.9 in ./.venv/lib/python3.11/site-packages (from typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio>=3.50.2->pycaret[full]) (0.12.0)
# Requirement already satisfied: typing-extensions~=4.0 in ./.venv/lib/python3.11/site-packages (from gradio>=3.50.2->pycaret[full]) (4.10.0)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.11/site-packages (from gradio-client==0.15.0->gradio>=3.50.2->pycaret[full]) (2024.3.1)
# Requirement already satisfied: websockets<12.0,>=10.0 in ./.venv/lib/python3.11/site-packages (from gradio-client==0.15.0->gradio>=3.50.2->pycaret[full]) (11.0.3)
# Requirement already satisfied: networkx>=2.2 in ./.venv/lib/python3.11/site-packages (from hyperopt>=0.2.7->pycaret[full]) (3.2.1)
# Requirement already satisfied: future in ./.venv/lib/python3.11/site-packages (from hyperopt>=0.2.7->pycaret[full]) (1.0.0)
# Requirement already satisfied: py4j in ./.venv/lib/python3.11/site-packages (from hyperopt>=0.2.7->pycaret[full]) (0.10.9.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.11/site-packages (from imbalanced-learn>=0.12.0->pycaret[full]) (3.4.0)
# Requirement already satisfied: zipp>=0.5 in ./.venv/lib/python3.11/site-packages (from importlib-metadata>=4.12.0->pycaret[full]) (3.18.1)
# Requirement already satisfied: interpret-core==0.6.0 in ./.venv/lib/python3.11/site-packages (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.0->interpret>=0.2.7->pycaret[full]) (0.6.0)
# Requirement already satisfied: dash-core-components>=1.0.0 in ./.venv/lib/python3.11/site-packages (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.0->interpret>=0.2.7->pycaret[full]) (2.0.0)
# Requirement already satisfied: dash-html-components>=1.0.0 in ./.venv/lib/python3.11/site-packages (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.0->interpret>=0.2.7->pycaret[full]) (2.0.0)
# Requirement already satisfied: dash-table>=4.1.0 in ./.venv/lib/python3.11/site-packages (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.0->interpret>=0.2.7->pycaret[full]) (5.0.0)
# Requirement already satisfied: dash-cytoscape>=0.1.1 in ./.venv/lib/python3.11/site-packages (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.0->interpret>=0.2.7->pycaret[full]) (1.0.0)
# Requirement already satisfied: gevent>=1.3.6 in ./.venv/lib/python3.11/site-packages (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.0->interpret>=0.2.7->pycaret[full]) (24.2.1)
# Requirement already satisfied: ipykernel>=4.10.0 in ./.venv/lib/python3.11/site-packages (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.0->interpret>=0.2.7->pycaret[full]) (6.29.4)
# Requirement already satisfied: SALib>=1.3.3 in ./.venv/lib/python3.11/site-packages (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.0->interpret>=0.2.7->pycaret[full]) (1.4.8)
# Requirement already satisfied: dill>=0.2.5 in ./.venv/lib/python3.11/site-packages (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.0->interpret>=0.2.7->pycaret[full]) (0.3.8)
# Requirement already satisfied: decorator in ./.venv/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret[full]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret[full]) (0.19.1)
# Requirement already satisfied: matplotlib-inline in ./.venv/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret[full]) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret[full]) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret[full]) (2.17.2)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret[full]) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in ./.venv/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret[full]) (5.14.2)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret[full]) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in ./.venv/lib/python3.11/site-packages (from ipywidgets>=7.6.5->pycaret[full]) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in ./.venv/lib/python3.11/site-packages (from ipywidgets>=7.6.5->pycaret[full]) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in ./.venv/lib/python3.11/site-packages (from ipywidgets>=7.6.5->pycaret[full]) (3.0.10)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret[full]) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret[full]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret[full]) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret[full]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret[full]) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret[full]) (2.9.0.post0)
# Requirement already satisfied: entrypoints<1 in ./.venv/lib/python3.11/site-packages (from mlflow>=2.0.0->pycaret[full]) (0.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in ./.venv/lib/python3.11/site-packages (from mlflow>=2.0.0->pycaret[full]) (3.1.43)
# Requirement already satisfied: protobuf<5,>=3.12.0 in ./.venv/lib/python3.11/site-packages (from mlflow>=2.0.0->pycaret[full]) (4.25.3)
# Requirement already satisfied: pytz<2025 in ./.venv/lib/python3.11/site-packages (from mlflow>=2.0.0->pycaret[full]) (2024.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in ./.venv/lib/python3.11/site-packages (from mlflow>=2.0.0->pycaret[full]) (0.4.4)
# Requirement already satisfied: alembic!=1.10.0,<2 in ./.venv/lib/python3.11/site-packages (from mlflow>=2.0.0->pycaret[full]) (1.13.1)
# Requirement already satisfied: docker<8,>=4.0.0 in ./.venv/lib/python3.11/site-packages (from mlflow>=2.0.0->pycaret[full]) (7.0.0)
# Requirement already satisfied: querystring-parser<2 in ./.venv/lib/python3.11/site-packages (from mlflow>=2.0.0->pycaret[full]) (1.2.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in ./.venv/lib/python3.11/site-packages (from mlflow>=2.0.0->pycaret[full]) (2.0.29)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in ./.venv/lib/python3.11/site-packages (from mlflow>=2.0.0->pycaret[full]) (15.0.2)
# Requirement already satisfied: markdown<4,>=3.3 in ./.venv/lib/python3.11/site-packages (from mlflow>=2.0.0->pycaret[full]) (3.6)
# Requirement already satisfied: graphene<4 in ./.venv/lib/python3.11/site-packages (from mlflow>=2.0.0->pycaret[full]) (3.3)
# Requirement already satisfied: gunicorn<22 in ./.venv/lib/python3.11/site-packages (from mlflow>=2.0.0->pycaret[full]) (21.2.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in ./.venv/lib/python3.11/site-packages (from flask->pycaret[full]) (2.1.2)
# Requirement already satisfied: blinker>=1.6.2 in ./.venv/lib/python3.11/site-packages (from flask->pycaret[full]) (1.7.0)
# Requirement already satisfied: cryptography>=3.3.1 in ./.venv/lib/python3.11/site-packages (from moto<5.0.0->pycaret[full]) (42.0.5)
# Requirement already satisfied: xmltodict in ./.venv/lib/python3.11/site-packages (from moto<5.0.0->pycaret[full]) (0.13.0)
# Requirement already satisfied: responses>=0.13.0 in ./.venv/lib/python3.11/site-packages (from moto<5.0.0->pycaret[full]) (0.25.0)
# Requirement already satisfied: fastjsonschema in ./.venv/lib/python3.11/site-packages (from nbformat>=4.2.0->pycaret[full]) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in ./.venv/lib/python3.11/site-packages (from nbformat>=4.2.0->pycaret[full]) (4.21.1)
# Requirement already satisfied: jupyter-core in ./.venv/lib/python3.11/site-packages (from nbformat>=4.2.0->pycaret[full]) (5.7.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in ./.venv/lib/python3.11/site-packages (from numba>=0.55.0->pycaret[full]) (0.42.0)
# Requirement already satisfied: colorlog in ./.venv/lib/python3.11/site-packages (from optuna>=3.0.0->pycaret[full]) (6.8.2)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.11/site-packages (from pandas<2.2.0->pycaret[full]) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in ./.venv/lib/python3.11/site-packages (from plotly>=5.14.0->pycaret[full]) (8.2.3)
# Requirement already satisfied: tsdownsample>=0.1.3 in ./.venv/lib/python3.11/site-packages (from plotly-resampler>=0.8.3.1->pycaret[full]) (0.1.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in ./.venv/lib/python3.11/site-packages (from pmdarima>=2.0.4->pycaret[full]) (3.0.10)
# Requirement already satisfied: urllib3 in ./.venv/lib/python3.11/site-packages (from pmdarima>=2.0.4->pycaret[full]) (1.26.18)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in ./.venv/lib/python3.11/site-packages (from pmdarima>=2.0.4->pycaret[full]) (65.5.0)
# Requirement already satisfied: iniconfig in ./.venv/lib/python3.11/site-packages (from pytest<8.0.0->pycaret[full]) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in ./.venv/lib/python3.11/site-packages (from pytest<8.0.0->pycaret[full]) (1.4.0)
# Requirement already satisfied: filelock in ./.venv/lib/python3.11/site-packages (from ray>=1.0.0->ray[tune]>=1.0.0; (python_version != "3.11" or platform_system != "Windows") and extra == "full"->pycaret[full]) (3.13.3)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./.venv/lib/python3.11/site-packages (from ray>=1.0.0->ray[tune]>=1.0.0; (python_version != "3.11" or platform_system != "Windows") and extra == "full"->pycaret[full]) (1.0.8)
# Requirement already satisfied: aiosignal in ./.venv/lib/python3.11/site-packages (from ray>=1.0.0->ray[tune]>=1.0.0; (python_version != "3.11" or platform_system != "Windows") and extra == "full"->pycaret[full]) (1.3.1)
# Requirement already satisfied: frozenlist in ./.venv/lib/python3.11/site-packages (from ray>=1.0.0->ray[tune]>=1.0.0; (python_version != "3.11" or platform_system != "Windows") and extra == "full"->pycaret[full]) (1.4.1)
# Requirement already satisfied: tensorboardX>=1.9 in ./.venv/lib/python3.11/site-packages (from ray[tune]>=1.0.0; (python_version != "3.11" or platform_system != "Windows") and extra == "full"->pycaret[full]) (2.6.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests>=2.27.1->pycaret[full]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.11/site-packages (from requests>=2.27.1->pycaret[full]) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.11/site-packages (from requests>=2.27.1->pycaret[full]) (2024.2.2)
# Requirement already satisfied: daal4py==2024.2.0 in ./.venv/lib/python3.11/site-packages (from scikit-learn-intelex>=2023.0.1->pycaret[full]) (2024.2.0)
# Requirement already satisfied: daal==2024.2.0 in ./.venv/lib/python3.11/site-packages (from daal4py==2024.2.0->scikit-learn-intelex>=2023.0.1->pycaret[full]) (2024.2.0)
# Requirement already satisfied: tbb==2021.* in ./.venv/lib/python3.11/site-packages (from daal==2024.2.0->daal4py==2024.2.0->scikit-learn-intelex>=2023.0.1->pycaret[full]) (2021.12.0)
# Requirement already satisfied: pyaml>=16.9 in ./.venv/lib/python3.11/site-packages (from scikit-optimize>=0.9.0->pycaret[full]) (23.12.0)
# Requirement already satisfied: slicer==0.0.7 in ./.venv/lib/python3.11/site-packages (from shap>=0.44.0->pycaret[full]) (0.0.7)
# Requirement already satisfied: scikit-base<0.8.0 in ./.venv/lib/python3.11/site-packages (from sktime>=0.26.0->pycaret[full]) (0.7.5)
# Requirement already satisfied: adagio>=0.2.4 in ./.venv/lib/python3.11/site-packages (from fugue->pycaret[full]) (0.2.4)
# Requirement already satisfied: qpd>=0.4.4 in ./.venv/lib/python3.11/site-packages (from fugue->pycaret[full]) (0.4.4)
# Requirement already satisfied: fugue-sql-antlr>=0.1.6 in ./.venv/lib/python3.11/site-packages (from fugue->pycaret[full]) (0.2.0)
# Requirement already satisfied: sqlglot in ./.venv/lib/python3.11/site-packages (from fugue->pycaret[full]) (23.6.4)
# Requirement already satisfied: fs in ./.venv/lib/python3.11/site-packages (from triad<0.9.2->pycaret[full]) (2.4.16)
# Requirement already satisfied: pynndescent>=0.5 in ./.venv/lib/python3.11/site-packages (from umap-learn>=0.5.2->pycaret[full]) (0.5.12)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.11/site-packages (from uvicorn>=0.17.6->pycaret[full]) (0.14.0)
# Requirement already satisfied: visions<0.7.7,>=0.7.5 in ./.venv/lib/python3.11/site-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling>=4.3.1->pycaret[full]) (0.7.6)
# Requirement already satisfied: htmlmin==0.1.12 in ./.venv/lib/python3.11/site-packages (from ydata-profiling>=4.3.1->pycaret[full]) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in ./.venv/lib/python3.11/site-packages (from ydata-profiling>=4.3.1->pycaret[full]) (0.12.4)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in ./.venv/lib/python3.11/site-packages (from ydata-profiling>=4.3.1->pycaret[full]) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in ./.venv/lib/python3.11/site-packages (from ydata-profiling>=4.3.1->pycaret[full]) (1.11.2)
# Requirement already satisfied: typeguard<5,>=4.1.2 in ./.venv/lib/python3.11/site-packages (from ydata-profiling>=4.3.1->pycaret[full]) (4.2.1)
# Requirement already satisfied: imagehash==4.3.1 in ./.venv/lib/python3.11/site-packages (from ydata-profiling>=4.3.1->pycaret[full]) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in ./.venv/lib/python3.11/site-packages (from ydata-profiling>=4.3.1->pycaret[full]) (1.9.3)
# Requirement already satisfied: dacite>=1.8 in ./.venv/lib/python3.11/site-packages (from ydata-profiling>=4.3.1->pycaret[full]) (1.8.1)
# Requirement already satisfied: PyWavelets in ./.venv/lib/python3.11/site-packages (from imagehash==4.3.1->ydata-profiling>=4.3.1->pycaret[full]) (1.6.0)
# Requirement already satisfied: retrying in ./.venv/lib/python3.11/site-packages (from dash[testing]; extra == "full"->pycaret[full]) (1.3.4)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.11/site-packages (from dash[testing]; extra == "full"->pycaret[full]) (1.6.0)
# Requirement already satisfied: beautifulsoup4>=4.8.2 in ./.venv/lib/python3.11/site-packages (from dash[testing]; extra == "full"->pycaret[full]) (4.12.3)
# Requirement already satisfied: lxml>=4.6.2 in ./.venv/lib/python3.11/site-packages (from dash[testing]; extra == "full"->pycaret[full]) (5.2.1)
# Requirement already satisfied: percy>=2.0.2 in ./.venv/lib/python3.11/site-packages (from dash[testing]; extra == "full"->pycaret[full]) (2.0.2)
# Requirement already satisfied: selenium<=4.2.0,>=3.141.0 in ./.venv/lib/python3.11/site-packages (from dash[testing]; extra == "full"->pycaret[full]) (4.2.0)
# Requirement already satisfied: multiprocess>=0.70.12 in ./.venv/lib/python3.11/site-packages (from dash[testing]; extra == "full"->pycaret[full]) (0.70.16)
# Requirement already satisfied: dash-testing-stub>=0.0.2 in ./.venv/lib/python3.11/site-packages (from dash[testing]; extra == "full"->pycaret[full]) (0.0.2)
# Requirement already satisfied: nltk>=3.6.7 in ./.venv/lib/python3.11/site-packages (from evidently->pycaret[full]) (3.8.1)
# Requirement already satisfied: litestar>=2.5.1 in ./.venv/lib/python3.11/site-packages (from evidently->pycaret[full]) (2.7.1)
# Requirement already satisfied: typing-inspect>=0.9.0 in ./.venv/lib/python3.11/site-packages (from evidently->pycaret[full]) (0.9.0)
# Requirement already satisfied: watchdog>=3 in ./.venv/lib/python3.11/site-packages (from evidently->pycaret[full]) (4.0.0)
# Requirement already satisfied: rich>=13 in ./.venv/lib/python3.11/site-packages (from evidently->pycaret[full]) (13.7.1)
# Requirement already satisfied: iterative-telemetry>=0.0.5 in ./.venv/lib/python3.11/site-packages (from evidently->pycaret[full]) (0.0.8)
# Requirement already satisfied: dynaconf>=3.2.4 in ./.venv/lib/python3.11/site-packages (from evidently->pycaret[full]) (3.2.5)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in ./.venv/lib/python3.11/site-packages (from fastapi->pycaret[full]) (0.37.2)
# Requirement already satisfied: dask<2023.7.1,>=2022.9.0 in ./.venv/lib/python3.11/site-packages (from dask[dataframe,distributed]<2023.7.1,>=2022.9.0; python_version >= "3.8" and extra == "dask"->fugue[dask]; extra == "full"->pycaret[full]) (2023.7.0)
# Requirement already satisfied: Mako in ./.venv/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow>=2.0.0->pycaret[full]) (1.3.2)
# Requirement already satisfied: toolz in ./.venv/lib/python3.11/site-packages (from altair<6.0,>=4.2.0->gradio>=3.50.2->pycaret[full]) (0.12.1)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.11/site-packages (from beautifulsoup4>=4.8.2->dash[testing]; extra == "full"->pycaret[full]) (2.5)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.11/site-packages (from cryptography>=3.3.1->moto<5.0.0->pycaret[full]) (1.16.0)
# Requirement already satisfied: partd>=1.2.0 in ./.venv/lib/python3.11/site-packages (from dask<2023.7.1,>=2022.9.0->dask[dataframe,distributed]<2023.7.1,>=2022.9.0; python_version >= "3.8" and extra == "dask"->fugue[dask]; extra == "full"->pycaret[full]) (1.4.1)
# Requirement already satisfied: distributed==2023.7.0 in ./.venv/lib/python3.11/site-packages (from dask[dataframe,distributed]<2023.7.1,>=2022.9.0; python_version >= "3.8" and extra == "dask"->fugue[dask]; extra == "full"->pycaret[full]) (2023.7.0)
# Requirement already satisfied: locket>=1.0.0 in ./.venv/lib/python3.11/site-packages (from distributed==2023.7.0->dask[dataframe,distributed]<2023.7.1,>=2022.9.0; python_version >= "3.8" and extra == "dask"->fugue[dask]; extra == "full"->pycaret[full]) (1.0.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in ./.venv/lib/python3.11/site-packages (from distributed==2023.7.0->dask[dataframe,distributed]<2023.7.1,>=2022.9.0; python_version >= "3.8" and extra == "dask"->fugue[dask]; extra == "full"->pycaret[full]) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in ./.venv/lib/python3.11/site-packages (from distributed==2023.7.0->dask[dataframe,distributed]<2023.7.1,>=2022.9.0; python_version >= "3.8" and extra == "dask"->fugue[dask]; extra == "full"->pycaret[full]) (3.0.0)
# Requirement already satisfied: tornado>=6.0.4 in ./.venv/lib/python3.11/site-packages (from distributed==2023.7.0->dask[dataframe,distributed]<2023.7.1,>=2022.9.0; python_version >= "3.8" and extra == "dask"->fugue[dask]; extra == "full"->pycaret[full]) (6.4)
# Requirement already satisfied: zict>=2.2.0 in ./.venv/lib/python3.11/site-packages (from distributed==2023.7.0->dask[dataframe,distributed]<2023.7.1,>=2022.9.0; python_version >= "3.8" and extra == "dask"->fugue[dask]; extra == "full"->pycaret[full]) (3.0.0)
# Requirement already satisfied: colour in ./.venv/lib/python3.11/site-packages (from dtreeviz>=2.1->explainerdashboard>=0.3.8->pycaret[full]) (0.1.5)
# Requirement already satisfied: wtforms in ./.venv/lib/python3.11/site-packages (from Flask-WTF>=1.1->explainerdashboard>=0.3.8->pycaret[full]) (3.1.2)
# Requirement already satisfied: antlr4-python3-runtime<4.12 in ./.venv/lib/python3.11/site-packages (from fugue-sql-antlr>=0.1.6->fugue->pycaret[full]) (4.11.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow>=2.0.0->pycaret[full]) (4.0.11)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in ./.venv/lib/python3.11/site-packages (from graphene<4->mlflow>=2.0.0->pycaret[full]) (3.2.3)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in ./.venv/lib/python3.11/site-packages (from graphene<4->mlflow>=2.0.0->pycaret[full]) (3.2.0)
# Requirement already satisfied: aniso8601<10,>=8 in ./.venv/lib/python3.11/site-packages (from graphene<4->mlflow>=2.0.0->pycaret[full]) (9.0.1)
# Requirement already satisfied: anyio in ./.venv/lib/python3.11/site-packages (from httpx>=0.24.1->gradio>=3.50.2->pycaret[full]) (4.3.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.11/site-packages (from httpx>=0.24.1->gradio>=3.50.2->pycaret[full]) (1.0.5)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.11/site-packages (from httpx>=0.24.1->gradio>=3.50.2->pycaret[full]) (1.3.1)
# Requirement already satisfied: appdirs in ./.venv/lib/python3.11/site-packages (from iterative-telemetry>=0.0.5->evidently->pycaret[full]) (1.4.4)
# Requirement already satisfied: distro in ./.venv/lib/python3.11/site-packages (from iterative-telemetry>=0.0.5->evidently->pycaret[full]) (1.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret[full]) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[full]) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[full]) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[full]) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[full]) (0.18.0)
# Requirement already satisfied: ansi2html in ./.venv/lib/python3.11/site-packages (from jupyter-dash>=0.4.1->explainerdashboard>=0.3.8->pycaret[full]) (1.9.1)
# Requirement already satisfied: msgspec>=0.18.2 in ./.venv/lib/python3.11/site-packages (from litestar>=2.5.1->evidently->pycaret[full]) (0.18.6)
# Requirement already satisfied: multidict>=6.0.2 in ./.venv/lib/python3.11/site-packages (from litestar>=2.5.1->evidently->pycaret[full]) (6.0.5)
# Requirement already satisfied: polyfactory>=2.6.3 in ./.venv/lib/python3.11/site-packages (from litestar>=2.5.1->evidently->pycaret[full]) (2.15.0)
# Requirement already satisfied: rich-click in ./.venv/lib/python3.11/site-packages (from litestar>=2.5.1->evidently->pycaret[full]) (1.7.4)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.11/site-packages (from nltk>=3.6.7->evidently->pycaret[full]) (2023.12.25)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.11/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret[full]) (0.7.0)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret[full]) (0.2.13)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.venv/lib/python3.11/site-packages (from pydantic>=2.0->gradio>=3.50.2->pycaret[full]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in ./.venv/lib/python3.11/site-packages (from pydantic>=2.0->gradio>=3.50.2->pycaret[full]) (2.16.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.11/site-packages (from rich>=13->evidently->pycaret[full]) (3.0.0)
# Requirement already satisfied: trio~=0.17 in ./.venv/lib/python3.11/site-packages (from selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "full"->pycaret[full]) (0.25.0)
# Requirement already satisfied: trio-websocket~=0.9 in ./.venv/lib/python3.11/site-packages (from selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "full"->pycaret[full]) (0.11.1)
# Requirement already satisfied: greenlet!=0.4.17 in ./.venv/lib/python3.11/site-packages (from sqlalchemy<3,>=1.4.0->mlflow>=2.0.0->pycaret[full]) (3.0.3)
# Requirement already satisfied: typer-slim==0.12.0 in ./.venv/lib/python3.11/site-packages (from typer-slim[standard]==0.12.0->typer<1.0,>=0.9->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio>=3.50.2->pycaret[full]) (0.12.0)
# Requirement already satisfied: typer-cli==0.12.0 in ./.venv/lib/python3.11/site-packages (from typer<1.0,>=0.9->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio>=3.50.2->pycaret[full]) (0.12.0)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.11/site-packages (from typer-slim[standard]==0.12.0->typer<1.0,>=0.9->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio>=3.50.2->pycaret[full]) (1.5.4)
# WARNING: typer 0.12.0 does not provide the extra 'all'
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.11/site-packages (from typing-inspect>=0.9.0->evidently->pycaret[full]) (1.0.0)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.11/site-packages (from jupyter-core->nbformat>=4.2.0->pycaret[full]) (4.2.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.11/site-packages (from stack-data->ipython>=5.5.0->pycaret[full]) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.11/site-packages (from stack-data->ipython>=5.5.0->pycaret[full]) (2.4.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.11/site-packages (from stack-data->ipython>=5.5.0->pycaret[full]) (0.2.2)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.3.1->moto<5.0.0->pycaret[full]) (2.22)
# Requirement already satisfied: zope.event in ./.venv/lib/python3.11/site-packages (from gevent>=1.3.6->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.0->interpret>=0.2.7->pycaret[full]) (5.0)
# Requirement already satisfied: zope.interface in ./.venv/lib/python3.11/site-packages (from gevent>=1.3.6->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.0->interpret>=0.2.7->pycaret[full]) (6.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow>=2.0.0->pycaret[full]) (5.0.1)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.11/site-packages (from ipykernel>=4.10.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.0->interpret>=0.2.7->pycaret[full]) (1.8.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.11/site-packages (from ipykernel>=4.10.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.0->interpret>=0.2.7->pycaret[full]) (8.6.1)
# Requirement already satisfied: pyzmq>=24 in ./.venv/lib/python3.11/site-packages (from ipykernel>=4.10.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.0->interpret>=0.2.7->pycaret[full]) (25.1.2)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13->evidently->pycaret[full]) (0.1.2)
# Requirement already satisfied: faker in ./.venv/lib/python3.11/site-packages (from polyfactory>=2.6.3->litestar>=2.5.1->evidently->pycaret[full]) (24.4.0)
# Requirement already satisfied: outcome in ./.venv/lib/python3.11/site-packages (from trio~=0.17->selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "full"->pycaret[full]) (1.3.0.post0)
# Requirement already satisfied: wsproto>=0.14 in ./.venv/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "full"->pycaret[full]) (1.2.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in ./.venv/lib/python3.11/site-packages (from urllib3[secure,socks]~=1.26->selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "full"->pycaret[full]) (24.1.0)
# Requirement already satisfied: urllib3-secure-extra in ./.venv/lib/python3.11/site-packages (from urllib3[secure,socks]~=1.26->selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "full"->pycaret[full]) (0.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in ./.venv/lib/python3.11/site-packages (from urllib3[secure,socks]~=1.26->selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "full"->pycaret[full]) (1.7.1)

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

# Load the diabetes dataset
diabetes = get_data('diabetes')

# Initialize setup
clf = setup(diabetes, target = 'Class variable', feature_selection = True)
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 187, number of negative: 350
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000052 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 609
# [LightGBM] [Info] Number of data points in the train set: 537, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.348231 -> initscore=-0.626825
# [LightGBM] [Info] Start training from score -0.626825
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# <style type="text/css">
# #T_23fba_row8_col1, #T_23fba_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_23fba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23fba_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_23fba_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23fba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23fba_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_23fba_row0_col1" class="data row0 col1" >3609</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_23fba_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_23fba_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_23fba_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_23fba_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_23fba_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_23fba_row3_col1" class="data row3 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_23fba_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_23fba_row4_col1" class="data row4 col1" >(768, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_23fba_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_23fba_row5_col1" class="data row5 col1" >(537, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_23fba_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_23fba_row6_col1" class="data row6 col1" >(231, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_23fba_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_23fba_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_23fba_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_23fba_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_23fba_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_23fba_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_23fba_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_23fba_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_23fba_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_23fba_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_23fba_row12_col0" class="data row12 col0" >Feature selection</td>
#       <td id="T_23fba_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_23fba_row13_col0" class="data row13 col0" >Feature selection method</td>
#       <td id="T_23fba_row13_col1" class="data row13 col1" >classic</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_23fba_row14_col0" class="data row14 col0" >Feature selection estimator</td>
#       <td id="T_23fba_row14_col1" class="data row14 col1" >lightgbm</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_23fba_row15_col0" class="data row15 col0" >Number of features selected</td>
#       <td id="T_23fba_row15_col1" class="data row15 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_23fba_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_23fba_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_23fba_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_23fba_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_23fba_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_23fba_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_23fba_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_23fba_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_23fba_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_23fba_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_23fba_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_23fba_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_23fba_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_23fba_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_23fba_row22_col1" class="data row22 col1" >daa9</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Compare models and select the best one
best_model = compare_models()
best_model
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         03:58:32
# Status                    Fitting 10 Folds
# Estimator  Light Gradient Boosting Machine
# <style type="text/css">
# #T_057e3 th {
#   text-align: left;
# }
# #T_057e3_row0_col0, #T_057e3_row0_col1, #T_057e3_row0_col2, #T_057e3_row0_col3, #T_057e3_row0_col4, #T_057e3_row0_col5, #T_057e3_row0_col6, #T_057e3_row0_col7, #T_057e3_row0_col8, #T_057e3_row1_col0, #T_057e3_row1_col1, #T_057e3_row1_col2, #T_057e3_row1_col3, #T_057e3_row1_col4, #T_057e3_row1_col5, #T_057e3_row1_col6, #T_057e3_row1_col7, #T_057e3_row1_col8, #T_057e3_row2_col0, #T_057e3_row2_col1, #T_057e3_row2_col2, #T_057e3_row2_col3, #T_057e3_row2_col4, #T_057e3_row2_col5, #T_057e3_row2_col6, #T_057e3_row2_col7, #T_057e3_row2_col8, #T_057e3_row3_col0, #T_057e3_row3_col1, #T_057e3_row3_col2, #T_057e3_row3_col3, #T_057e3_row3_col4, #T_057e3_row3_col5, #T_057e3_row3_col6, #T_057e3_row3_col7, #T_057e3_row3_col8, #T_057e3_row4_col0, #T_057e3_row4_col1, #T_057e3_row4_col2, #T_057e3_row4_col3, #T_057e3_row4_col4, #T_057e3_row4_col5, #T_057e3_row4_col6, #T_057e3_row4_col7, #T_057e3_row4_col8, #T_057e3_row5_col0, #T_057e3_row5_col1, #T_057e3_row5_col2, #T_057e3_row5_col3, #T_057e3_row5_col4, #T_057e3_row5_col5, #T_057e3_row5_col6, #T_057e3_row5_col7, #T_057e3_row5_col8, #T_057e3_row6_col0, #T_057e3_row6_col1, #T_057e3_row6_col2, #T_057e3_row6_col3, #T_057e3_row6_col4, #T_057e3_row6_col5, #T_057e3_row6_col6, #T_057e3_row6_col7, #T_057e3_row6_col8, #T_057e3_row7_col0, #T_057e3_row7_col1, #T_057e3_row7_col2, #T_057e3_row7_col3, #T_057e3_row7_col4, #T_057e3_row7_col5, #T_057e3_row7_col6, #T_057e3_row7_col7, #T_057e3_row7_col8, #T_057e3_row8_col0, #T_057e3_row8_col1, #T_057e3_row8_col2, #T_057e3_row8_col3, #T_057e3_row8_col4, #T_057e3_row8_col5, #T_057e3_row8_col6, #T_057e3_row8_col7, #T_057e3_row8_col8, #T_057e3_row9_col0, #T_057e3_row9_col1, #T_057e3_row9_col2, #T_057e3_row9_col3, #T_057e3_row9_col4, #T_057e3_row9_col5, #T_057e3_row9_col6, #T_057e3_row9_col7, #T_057e3_row9_col8, #T_057e3_row10_col0, #T_057e3_row10_col1, #T_057e3_row10_col2, #T_057e3_row10_col3, #T_057e3_row10_col4, #T_057e3_row10_col5, #T_057e3_row10_col6, #T_057e3_row10_col7, #T_057e3_row10_col8, #T_057e3_row11_col0, #T_057e3_row11_col1, #T_057e3_row11_col2, #T_057e3_row11_col3, #T_057e3_row11_col4, #T_057e3_row11_col5, #T_057e3_row11_col6, #T_057e3_row11_col7, #T_057e3_row11_col8, #T_057e3_row12_col0, #T_057e3_row12_col1, #T_057e3_row12_col2, #T_057e3_row12_col3, #T_057e3_row12_col4, #T_057e3_row12_col5, #T_057e3_row12_col6, #T_057e3_row12_col7, #T_057e3_row12_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_057e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_057e3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_057e3_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_057e3_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_057e3_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_057e3_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_057e3_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_057e3_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_057e3_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_057e3_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_057e3_level0_row0" class="row_heading level0 row0" >qda</th>
#       <td id="T_057e3_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_057e3_row0_col1" class="data row0 col1" >0.6892</td>
#       <td id="T_057e3_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_057e3_row0_col3" class="data row0 col3" >0.2696</td>
#       <td id="T_057e3_row0_col4" class="data row0 col4" >0.6114</td>
#       <td id="T_057e3_row0_col5" class="data row0 col5" >0.3632</td>
#       <td id="T_057e3_row0_col6" class="data row0 col6" >0.2079</td>
#       <td id="T_057e3_row0_col7" class="data row0 col7" >0.2376</td>
#       <td id="T_057e3_row0_col8" class="data row0 col8" >1.5890</td>
#     </tr>
#     <tr>
#       <th id="T_057e3_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_057e3_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_057e3_row1_col1" class="data row1 col1" >0.6874</td>
#       <td id="T_057e3_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_057e3_row1_col3" class="data row1 col3" >0.2594</td>
#       <td id="T_057e3_row1_col4" class="data row1 col4" >0.5942</td>
#       <td id="T_057e3_row1_col5" class="data row1 col5" >0.3474</td>
#       <td id="T_057e3_row1_col6" class="data row1 col6" >0.1986</td>
#       <td id="T_057e3_row1_col7" class="data row1 col7" >0.2256</td>
#       <td id="T_057e3_row1_col8" class="data row1 col8" >2.6110</td>
#     </tr>
#     <tr>
#       <th id="T_057e3_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_057e3_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_057e3_row2_col1" class="data row2 col1" >0.6874</td>
#       <td id="T_057e3_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_057e3_row2_col3" class="data row2 col3" >0.2699</td>
#       <td id="T_057e3_row2_col4" class="data row2 col4" >0.5979</td>
#       <td id="T_057e3_row2_col5" class="data row2 col5" >0.3584</td>
#       <td id="T_057e3_row2_col6" class="data row2 col6" >0.2034</td>
#       <td id="T_057e3_row2_col7" class="data row2 col7" >0.2303</td>
#       <td id="T_057e3_row2_col8" class="data row2 col8" >1.5720</td>
#     </tr>
#     <tr>
#       <th id="T_057e3_level0_row3" class="row_heading level0 row3" >nb</th>
#       <td id="T_057e3_row3_col0" class="data row3 col0" >Naive Bayes</td>
#       <td id="T_057e3_row3_col1" class="data row3 col1" >0.6855</td>
#       <td id="T_057e3_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_057e3_row3_col3" class="data row3 col3" >0.2696</td>
#       <td id="T_057e3_row3_col4" class="data row3 col4" >0.5959</td>
#       <td id="T_057e3_row3_col5" class="data row3 col5" >0.3608</td>
#       <td id="T_057e3_row3_col6" class="data row3 col6" >0.2008</td>
#       <td id="T_057e3_row3_col7" class="data row3 col7" >0.2277</td>
#       <td id="T_057e3_row3_col8" class="data row3 col8" >1.7540</td>
#     </tr>
#     <tr>
#       <th id="T_057e3_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_057e3_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_057e3_row4_col1" class="data row4 col1" >0.6725</td>
#       <td id="T_057e3_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_057e3_row4_col3" class="data row4 col3" >0.2751</td>
#       <td id="T_057e3_row4_col4" class="data row4 col4" >0.5460</td>
#       <td id="T_057e3_row4_col5" class="data row4 col5" >0.3563</td>
#       <td id="T_057e3_row4_col6" class="data row4 col6" >0.1784</td>
#       <td id="T_057e3_row4_col7" class="data row4 col7" >0.1962</td>
#       <td id="T_057e3_row4_col8" class="data row4 col8" >2.3660</td>
#     </tr>
#     <tr>
#       <th id="T_057e3_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_057e3_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_057e3_row5_col1" class="data row5 col1" >0.6706</td>
#       <td id="T_057e3_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_057e3_row5_col3" class="data row5 col3" >0.2199</td>
#       <td id="T_057e3_row5_col4" class="data row5 col4" >0.6020</td>
#       <td id="T_057e3_row5_col5" class="data row5 col5" >0.3111</td>
#       <td id="T_057e3_row5_col6" class="data row5 col6" >0.1531</td>
#       <td id="T_057e3_row5_col7" class="data row5 col7" >0.1911</td>
#       <td id="T_057e3_row5_col8" class="data row5 col8" >2.0240</td>
#     </tr>
#     <tr>
#       <th id="T_057e3_level0_row6" class="row_heading level0 row6" >gbc</th>
#       <td id="T_057e3_row6_col0" class="data row6 col0" >Gradient Boosting Classifier</td>
#       <td id="T_057e3_row6_col1" class="data row6 col1" >0.6556</td>
#       <td id="T_057e3_row6_col2" class="data row6 col2" >0.0000</td>
#       <td
# Processing:   0%|          | 0/69 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Compare models and select the best one
# ----> 2 best_model = compare_models()
#       3 best_model
#
# File ~/apps/mti-ml-guide/.venv/lib/python3.11/site-packages/pycaret/utils/generic.py:964, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     962     if globals_d[name] is None:
#     963         raise ValueError(message)
# --> 964 return func(*args, **kwargs)
#
# File ~/apps/mti-ml-guide/.venv/lib/python3.11/site-packages/pycaret/classification/functional.py:814, in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, engine, verbose, parallel)
#     672 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#     673 def compare_models(
#     674     include: Optional[List[Union[str, Any]]] = None,
#    (...)
#     690     parallel: Optional[ParallelBackend] = None,
#     691 ) -> Union[Any, List[Any]]:
#     692     """
#     693     This function trains and evaluates performance of all estimators available in the
#     694     model library using cross validation. The output of this function is a score grid
#    (...)
#     811     - No models are logged in ``MLFlow`` when ``cross_validation`` parameter is False.
#     812     """
# --> 814     return _CURRENT_EXPERIMENT.compare_models(
#     815         include=include,
#     816         exclude=exclude,
#     817         fold=fold,
#     818         round=round,
#     819         cross_validation=cross_validation,
#     820         sort=sort,
#     821         n_select=n_select,
#     822         budget_time=budget_time,
#     823         turbo=turbo,
#     824         errors=errors,
#     825         fit_kwargs=fit_kwargs,
#     826         groups=groups,
#     827         experiment_custom_tags=experiment_custom_tags,
#     828         probability_threshold=probability_threshold,
#     829         engine=engine,
#     830         verbose=verbose,
#     831         parallel=parallel,
#     832     )
#
# File ~/apps/mti-ml-guide/.venv/lib/python3.11/site-packages/pycaret/classification/oop.py:1180, in ClassificationExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, engine, verbose, parallel)
#    1177         self._set_engine(estimator=estimator, engine=eng, severity="error")
#    1179 try:
# -> 1180     return_values = super().compare_models(
#    1181         include=include,
#    1182         exclude=exclude,
#    1183         fold=fold,
#    1184         round=round,
#    1185         cross_validation=cross_validation,
#    1186         sort=sort,
#    1187         n_select=n_select,
#    1188         budget_time=budget_time,
#    1189         turbo=turbo,
#    1190         errors=errors,
#    1191         fit_kwargs=fit_kwargs,
#    1192         groups=groups,
#    1193         experiment_custom_tags=experiment_custom_tags,
#    1194         verbose=verbose,
#    1195         probability_threshold=probability_threshold,
#    1196         parallel=parallel,
#    1197         caller_params=caller_params,
#    1198     )
#    1199 finally:
#    1200     if engine is not None:
#    1201         # Reset the models back to the default engines
#
# File ~/apps/mti-ml-guide/.venv/lib/python3.11/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:794, in _SupervisedExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, verbose, parallel, caller_params)
#     791 results_columns_to_ignore = ["Object", "runtime", "cutoff"]
#     793 try:
# --> 794     model, model_fit_time = self._create_model(**create_model_args)
#     795     model_results = self.pull(pop=True)
#     796     assert (
#     797         np.sum(
#     798             model_results.drop(
#    (...)
#     802         != 0.0
#     803     )
#
# File ~/apps/mti-ml-guide/.venv/lib/python3.11/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:1533, in _SupervisedExperiment._create_model(self, estimator, fold, round, cross_validation, predict, fit_kwargs, groups, refit, probability_threshold, experiment_custom_tags, verbose, system, add_to_model_list, X_train_data, y_train_data, metrics, display, model_only, return_train_score, error_score, **kwargs)
#    1530         return model, model_fit_time
#    1531     return model
# -> 1533 model, model_fit_time, model_results, _ = self._create_model_with_cv(
#    1534     model=model,
#    1535     data_X=data_X,
#    1536     data_y=data_y,
#    1537     fit_kwargs=fit_kwargs,
#    1538     round=round,
#    1539     cv=cv,
#    1540     groups=groups,
#    1541     metrics=metrics,
#    1542     refit=refit,
#    1543     system=system,
#    1544     display=display,
#    1545     error_score=error_score,
#    1546     return_train_score=return_train_score,
#    1547 )
#    1549 # end runtime
#    1550 runtime_end = time.time()
#
# File ~/apps/mti-ml-guide/.venv/lib/python3.11/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:1126, in _SupervisedExperiment._create_model_with_cv(self, model, data_X, data_y, fit_kwargs, round, cv, groups, metrics, refit, system, display, error_score, return_train_score)
#    1124     model_fit_start = time.time()
#    1125     with redirect_output(self.logger):
# -> 1126         scores = cross_validate(
#    1127             pipeline_with_model,
#    1128             data_X,
#    1129             data_y,
#    1130             cv=cv,
#    1131             groups=groups,
#    1132             scoring=metrics_dict,
#    1133             params=fit_kwargs,
#    1134             n_jobs=n_jobs,
#    1135             return_train_score=return_train_score,
#    1136             error_score=error_score,
#    1137         )
#    1139 model_fit_end = time.time()
#    1140 model_fit_time = np.array(model_fit_end - model_fit_start).round(2)
#
# File ~/apps/mti-ml-guide/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/apps/mti-ml-guide/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:430, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     427 # We clone the estimator to make sure that all the folds are
#     428 # independent, and that it is pickle-able.
#     429 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 430 results = parallel(
#     431     delayed(_fit_and_score)(
#     432         clone(estimator),
#     433         X,
#     434         y,
#     435         scorer=scorers,
#     436         train=train,
#     437         test=test,
#     438         verbose=verbose,
#     439         parameters=None,
#     440         fit_params=routed_params.estimator.fit,
#     441         score_params=routed_params.scorer.score,
#     442         return_train_score=return_train_score,
#     443         return_times=True,
#     444         return_estimator=return_estimator,
#     445         error_score=error_score,
#     446     )
#     447     for train, test in indices
#     448 )
#     450 _warn_or_raise_about_fit_failures(results, error_score)
#     452 # For callable scoring, the return type is only know after calling. If the
#     453 # return type is a dictionary, the error scores can now be inserted with
#     454 # the correct key.
#
# File ~/apps/mti-ml-guide/.venv/lib/python3.11/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File ~/apps/mti-ml-guide/.venv/lib/python3.11/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~/apps/mti-ml-guide/.venv/lib/python3.11/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File ~/apps/mti-ml-guide/.venv/lib/python3.11/site-packages/joblib/parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
# Get the selected features
selected_features = get_config('X').columns

print("Selected Features: ", selected_features)
